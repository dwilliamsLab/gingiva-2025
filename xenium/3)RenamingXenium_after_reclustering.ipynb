# %%
import scimap as sm
import pandas as pd
import sys
import os
import scanpy as sc
import seaborn as sns; sns.set(color_codes=True)
import anndata
adata = anndata.read_h5ad('/data/vasileiosionat2/Xenium/Drake_outputs/ccProcessed.h5ad')

# %%
print(adata.obs['Lvl5'].unique().tolist())

# %%
print(adata.obs['B_leiden'].unique().tolist())

# %%
adata.obs['Lvl5'] = adata.obs['Lvl5'].astype(str)
# Convert the 'niche_cc14' column to categorical
adata.obs['Lvl5'] = pd.Categorical(adata.obs['Lvl5'])

# Define the replacement dictionary
replacement_dict = {
    'T.CCR7hi': 'Oth.CCR7hi',
    'VEC.vein1': 'VEC.1',
    'VEC.art3': 'VEC.2',
    'VEC.art1': 'VEC.3',
    'VEC.cap': 'VEC.4',
    'VEC.art2' : 'VEC.5.1',
    'VEC.vein2' : 'VEC.5.2',
   }


# Replace values in the 'niche_cc14' column
adata.obs['Lvl5'] = adata.obs['Lvl5'].replace(replacement_dict)
print(adata.obs['Lvl5'].unique().tolist())

# %%
print(adata.obs['Lvl4'].unique().tolist())

# %%
adata.obs['Lvl4'] = adata.obs['Lvl5']

# %%
adata.obs['Lvl4'] = adata.obs['Lvl4'].astype(str)
# Convert the 'niche_cc14' column to categorical
adata.obs['Lvl4'] = pd.Categorical(adata.obs['Lvl4'])

# Define the replacement dictionary
replacement_dict = {
    'VEC.5.1': 'VEC.5',
    'VEC.5.2': 'VEC.5',
    'Pl.2.1': 'Pl.2',
    'Pl.2.2': 'Pl.2',
    'T.CCL5hi': 'Tc',
    'T.GZMKhi':'Tc',
    'T.GZMAhi':'Tc',
    'T.CD8Ahi': 'Tc',
    'Lang.prol' : 'Lang'
   }


# Replace values in the 'niche_cc14' column
adata.obs['Lvl4'] = adata.obs['Lvl4'].replace(replacement_dict)
print(adata.obs['Lvl4'].unique().tolist())

# %%
import pandas as pd

# Assuming adata.obs contains 'Lvl4' and 'Lvl5'
cluster_counts = (
    adata.obs.groupby(['Lvl4', 'Lvl5']).size().unstack(fill_value=0)
)

# Adjust Pandas display settings to show all rows and all columns
pd.set_option('display.max_columns', None)  # Show all columns
pd.set_option('display.max_rows', None)     # Show all rows
pd.set_option('display.width', None)       # Avoid line breaks for wide DataFrames

# Display the full result
print(cluster_counts)

# Reset the options if needed (optional)
pd.reset_option('display.max_columns')
pd.reset_option('display.max_rows')
pd.reset_option('display.width')

# %%
import pandas as pd

# Assuming adata.obs contains 'Lvl4' and 'Lvl5'
cluster_counts = (
    adata.obs.groupby(['Lvl3', 'Lvl4']).size().unstack(fill_value=0)
)

# Adjust Pandas display settings to show all rows and all columns
pd.set_option('display.max_columns', None)  # Show all columns
pd.set_option('display.max_rows', None)     # Show all rows
pd.set_option('display.width', None)       # Avoid line breaks for wide DataFrames

# Display the full result
print(cluster_counts)

# Reset the options if needed (optional)
pd.reset_option('display.max_columns')
pd.reset_option('display.max_rows')
pd.reset_option('display.width')

# %%
adata.obs['Lvl3'] = adata.obs['Lvl4']

# %%
# Convert to string type to handle duplicates
adata.obs['Lvl3'] = adata.obs['Lvl3'].astype(str)

# Replace categories starting with "Oth." with "Other"
adata.obs['Lvl3'] = adata.obs['Lvl3'].replace(r"^Oth\..*", "Other", regex=True)

# Convert back to categorical type
adata.obs['Lvl3'] = adata.obs['Lvl3'].astype('category')

# %%
print(adata.obs['Lvl3'].unique().tolist())

# %%
# Convert to string type to handle duplicates
adata.obs['Lvl3'] = adata.obs['Lvl3'].astype(str)

# Replace categories starting with "Oth." with "Other"
adata.obs['Lvl3'] = adata.obs['Lvl3'].replace(r"^VEC\..*", "VEC", regex=True)

# Convert back to categorical type
adata.obs['Lvl3'] = adata.obs['Lvl3'].astype('category')

# %%
print(adata.obs['Lvl3'].unique().tolist())

# %%
# Convert to string type to handle duplicates
adata.obs['Lvl3'] = adata.obs['Lvl3'].astype(str)

# Replace categories starting with "Oth." or containing "Mix" with "Other"
adata.obs['Lvl3'] = adata.obs['Lvl3'].replace(r"(^Unc..*|.*Mix.*)", "Other", regex=True)

# Convert back to categorical type
adata.obs['Lvl3'] = adata.obs['Lvl3'].astype('category')

# %%
# Convert to string type to handle duplicates
adata.obs['Lvl3'] = adata.obs['Lvl3'].astype(str)

# Replace categories starting with "Oth." or containing "Mix" with "Other"
adata.obs['Lvl3'] = adata.obs['Lvl3'].replace(r"^Fib..*", "Fib", regex=True)

# Convert back to categorical type
adata.obs['Lvl3'] = adata.obs['Lvl3'].astype('category')

# %%
# Convert to string type to handle duplicates
adata.obs['Lvl3'] = adata.obs['Lvl3'].astype(str)

# Replace categories starting with "Oth." or containing "Mix" with "Other"
adata.obs['Lvl3'] = adata.obs['Lvl3'].replace(r"^Ep.Cr..*", "Crev", regex=True)

# Convert back to categorical type
adata.obs['Lvl3'] = adata.obs['Lvl3'].astype('category')

# %%
# Convert to string type to handle duplicates
adata.obs['Lvl3'] = adata.obs['Lvl3'].astype(str)

# Replace categories starting with "Oth." or containing "Mix" with "Other"
adata.obs['Lvl3'] = adata.obs['Lvl3'].replace(r"(^Ep.B.*|.*Mix.*)", "Basal", regex=True)

# Convert back to categorical type
adata.obs['Lvl3'] = adata.obs['Lvl3'].astype('category')

# %%
# Convert to string type to handle duplicates
adata.obs['Lvl3'] = adata.obs['Lvl3'].astype(str)

# Replace categories starting with "Oth." or containing "Mix" with "Other"
adata.obs['Lvl3'] = adata.obs['Lvl3'].replace(r"^Ep.PB..*", "Spinous", regex=True)

# Convert back to categorical type
adata.obs['Lvl3'] = adata.obs['Lvl3'].astype('category')

# %%
# Convert to string type to handle duplicates
adata.obs['Lvl3'] = adata.obs['Lvl3'].astype(str)

# Replace categories starting with "Oth." or containing "Mix" with "Other"
adata.obs['Lvl3'] = adata.obs['Lvl3'].replace(r"^Ep.S..*", "Spinous", regex=True)

# Convert back to categorical type
adata.obs['Lvl3'] = adata.obs['Lvl3'].astype('category')

# %%
# Convert to string type to handle duplicates
adata.obs['Lvl3'] = adata.obs['Lvl3'].astype(str)

# Replace categories starting with "Oth." or containing "Mix" with "Other"
adata.obs['Lvl3'] = adata.obs['Lvl3'].replace(r"^Pl..*", "Plasma", regex=True)

# Convert back to categorical type
adata.obs['Lvl3'] = adata.obs['Lvl3'].astype('category')

# %%
# Convert to string type to handle duplicates
adata.obs['Lvl3'] = adata.obs['Lvl3'].astype(str)

# Replace categories starting with "Oth." or containing "Mix" with "Other"
adata.obs['Lvl3'] = adata.obs['Lvl3'].replace(r"^P..*", "Plasma", regex=True)

# Convert back to categorical type
adata.obs['Lvl3'] = adata.obs['Lvl3'].astype('category')

# %%
# Convert to string type to handle duplicates
adata.obs['Lvl3'] = adata.obs['Lvl3'].astype(str)

# Replace categories starting with "Oth." or containing "Mix" with "Other"
adata.obs['Lvl3'] = adata.obs['Lvl3'].replace(r"^T_prox..*", "T.other", regex=True)

# Convert back to categorical type
adata.obs['Lvl3'] = adata.obs['Lvl3'].astype('category')

# %%
# Convert to string type to handle duplicates
adata.obs['Lvl3'] = adata.obs['Lvl3'].astype(str)

# Replace categories starting with "Oth." or containing "Mix" with "Other"
adata.obs['Lvl3'] = adata.obs['Lvl3'].replace(r"^Th_prox..*", "Th", regex=True)

# Convert back to categorical type
adata.obs['Lvl3'] = adata.obs['Lvl3'].astype('category')

# %%
# Convert to string type to handle duplicates
adata.obs['Lvl3'] = adata.obs['Lvl3'].astype(str)

# Replace categories based on conditions
adata.obs['Lvl3'] = adata.obs['Lvl3'].replace({
    r".*DC.*": "DC"        # Contains "DC"
}, regex=True)

# Convert back to categorical type
adata.obs['Lvl3'] = adata.obs['Lvl3'].astype('category')

# %%
# Convert to string type to handle duplicates
adata.obs['Lvl3'] = adata.obs['Lvl3'].astype(str)

# Replace categories based on conditions
adata.obs['Lvl3'] = adata.obs['Lvl3'].replace({
    "Ep.K": "Keratin"        # Contains "DC"
}, regex=True)

# Convert back to categorical type
adata.obs['Lvl3'] = adata.obs['Lvl3'].astype('category')

# %%
# Convert to string type to handle duplicates
adata.obs['Lvl3'] = adata.obs['Lvl3'].astype(str)

# Replace categories based on conditions
adata.obs['Lvl3'] = adata.obs['Lvl3'].replace({
    "Ep.prol": "Prol"        # Contains "DC"
}, regex=True)

# Convert back to categorical type
adata.obs['Lvl3'] = adata.obs['Lvl3'].astype('category')

# %%
# Convert to string type to handle duplicates
adata.obs['Lvl3'] = adata.obs['Lvl3'].astype(str)

# Replace categories based on conditions
adata.obs['Lvl3'] = adata.obs['Lvl3'].replace({
    "T.IL7Rhi": "T.other"        # Contains "DC"
}, regex=True)

# Convert back to categorical type
adata.obs['Lvl3'] = adata.obs['Lvl3'].astype('category')

# %%
import pandas as pd

# Assuming adata.obs contains 'Lvl4' and 'Lvl5'
cluster_counts = (
    adata.obs.groupby(['Lvl3', 'Lvl4']).size().unstack(fill_value=0)
)

# Adjust Pandas display settings to show all rows and all columns
pd.set_option('display.max_columns', None)  # Show all columns
pd.set_option('display.max_rows', None)     # Show all rows
pd.set_option('display.width', None)       # Avoid line breaks for wide DataFrames

# Display the full result
print(cluster_counts)

# Reset the options if needed (optional)
pd.reset_option('display.max_columns')
pd.reset_option('display.max_rows')
pd.reset_option('display.width')

# %%
adata.obs['Lvl2.5'] = adata.obs['Lvl3']

# %%
print(adata.obs['Lvl2.5'].unique().tolist())

# %%
# Convert to string type to handle duplicates
adata.obs['Lvl2.5'] = adata.obs['Lvl2.5'].astype(str)

# Replace categories based on conditions
adata.obs['Lvl2.5'] = adata.obs['Lvl2.5'].replace({
    r"^T..*": "T"        # Contains "DC"
}, regex=True)

# Convert back to categorical type
adata.obs['Lvl2.5'] = adata.obs['Lvl2.5'].astype('category')

# %%
adata.obs['Lvl2'] = adata.obs['Lvl2.5']

# %%
adata.obs['Lvl2'] = adata.obs['Lvl2'].astype(str)
# Convert the 'niche_cc14' column to categorical
adata.obs['Lvl2'] = pd.Categorical(adata.obs['Lvl2'])

# Define the replacement dictionary
replacement_dict = {
    'T': 'T/NK',
    'NK': 'T/NK',
    'B': 'B/Plasma',
    'Plasma': 'B/Plasma',
    'MyoF': 'Fibroblast',
    'Fib':'Fibroblast',
    'VEC':'Vascular',
    'LEC': 'Vascular',
    'SMC': 'Vascular',
    'Mono' : 'Myeloid',
    'Mac' : 'Myeloid',
    'DC' : 'Myeloid',
    'Lang' : 'Myeloid',
    'Mast' : 'Myeloid',
    'Basal' : 'Oral Epi',
    'Spinous' : 'Oral Epi',
    'Prol' : 'Oral Epi',
    'Keratin' : 'Oral Epi',
    'Crev' : 'Crevicular Epi'
   }


# Replace values in the 'niche_cc14' column
adata.obs['Lvl2'] = adata.obs['Lvl2'].replace(replacement_dict)
print(adata.obs['Lvl2'].unique().tolist())

# %%
import pandas as pd

# Assuming adata.obs contains 'Lvl4' and 'Lvl5'
cluster_counts = (
    adata.obs.groupby(['Lvl2', 'Lvl2.5']).size().unstack(fill_value=0)
)

# Adjust Pandas display settings to show all rows and all columns
pd.set_option('display.max_columns', None)  # Show all columns
pd.set_option('display.max_rows', None)     # Show all rows
pd.set_option('display.width', None)       # Avoid line breaks for wide DataFrames

# Display the full result
print(cluster_counts)

# Reset the options if needed (optional)
pd.reset_option('display.max_columns')
pd.reset_option('display.max_rows')
pd.reset_option('display.width')

# %%
adata.obs['Lvl1'] = adata.obs['Lvl2']

# %%
adata.obs['Lvl1'] = adata.obs['Lvl1'].astype(str)
# Convert the 'niche_cc14' column to categorical
adata.obs['Lvl1'] = pd.Categorical(adata.obs['Lvl1'])

# Define the replacement dictionary
replacement_dict = {
    'T/NK' : 'Immune',
    'B/Plasma' : 'Immune',
    'Myeloid': 'Immune',
    'Oral Epi' : 'Epithelial',
    'Crevicular Epi' : 'Epithelial',
    'Mel' : 'Other',
    'Neur': 'Other' 
   }


# Replace values in the 'niche_cc14' column
adata.obs['Lvl1'] = adata.obs['Lvl1'].replace(replacement_dict)
print(adata.obs['Lvl1'].unique().tolist())

# %%
import pandas as pd

# Assuming adata.obs contains 'Lvl4' and 'Lvl5'
cluster_counts = (
    adata.obs.groupby(['Lvl1', 'Lvl2']).size().unstack(fill_value=0)
)

# Adjust Pandas display settings to show all rows and all columns
pd.set_option('display.max_columns', None)  # Show all columns
pd.set_option('display.max_rows', None)     # Show all rows
pd.set_option('display.width', None)       # Avoid line breaks for wide DataFrames

# Display the full result
print(cluster_counts)

# Reset the options if needed (optional)
pd.reset_option('display.max_columns')
pd.reset_option('display.max_rows')
pd.reset_option('display.width')

# %%
#After T cell clustering save
adata.write_h5ad("/data/vasileiosionat2/Xenium/Drake_outputs/ccProcessed.h5ad")

# %%
print(adata.obs['Lvl2'].unique().tolist())

# %%
import scanpy as sc

# Step 1: Ensure all observation names are unique
adata.obs_names_make_unique()

# Step 2: Subset the data to include categories starting with 'T-' or equal to 'B'
adata_subset = adata[(adata.obs['Lvl4'].isin(['Treg', 'Th_proximity_to_B', 'Th', 'T.IL7Rhi', 'T.IE', 
    'NK', 'Tc', 'T_proximity_to_Fib', 'T_proximity_to_BV']))].copy()

# Step 3: Log-transform the data if not already done
sc.pp.log1p(adata_subset)

# Step 4: Perform differential expression analysis using the Wilcoxon method
sc.tl.rank_genes_groups(adata_subset, 'Lvl4', method='wilcoxon', use_raw=False)

# Step 5: Extract top marker genes for each cluster
top_genes_per_cluster = {}
for cluster in adata_subset.obs['Lvl4'].cat.categories:
    top_genes_per_cluster[cluster] = adata_subset.uns['rank_genes_groups']['names'][cluster][:20]  # Top 20 genes

# Step 6: Generate dendrogram for cluster ordering
sc.tl.dendrogram(adata_subset, groupby='Lvl4')

# Step 7: Retrieve the cluster order based on the dendrogram
cluster_order = adata_subset.uns['dendrogram_Lvl4']['categories_ordered']

# Step 8: Filter genes based on 20% expression threshold
filtered_genes = set()
for cluster in cluster_order:
    cluster_data = adata_subset[adata_subset.obs['Lvl4'] == cluster]
    # Calculate the fraction of cells expressing each gene in the cluster
    gene_expression_fraction = (cluster_data.X > 0).mean(axis=0).A1  # Sparse matrix to 1D array
    genes_above_threshold = cluster_data.var_names[gene_expression_fraction > 0.2]
    filtered_genes.update(genes_above_threshold)

# Step 9: Ensure unique genes for plotting
unique_genes = set()
genes_for_plot = []

for cluster in cluster_order:
    if cluster in top_genes_per_cluster:
        cluster_genes = top_genes_per_cluster[cluster]
        genes_for_this_cluster = []
        for gene in cluster_genes:
            if len(genes_for_this_cluster) >= 5:
                break
            if gene in filtered_genes and gene not in unique_genes:
                unique_genes.add(gene)
                genes_for_this_cluster.append(gene)
        genes_for_plot.extend(genes_for_this_cluster)

# Step 10: Plot the dotplot with the filtered genes, swapping axes if necessary
sc.pl.dotplot(
    adata_subset,
    var_names=genes_for_plot,
    groupby='Lvl4',
    dendrogram=True,
    use_raw=False,
    cmap="vlag",
    standard_scale='var',
    swap_axes=True
)

# %%
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.backends.backend_pdf import PdfPages
import os


rotation_angle = 30  # Define rotation for this sample

# Specify the directory where you want to save the PDF
save_directory = '/data/vasileiosionat2/Xenium/Figures/lvl4_pdf/'
pdf_filename = os.path.join(save_directory, f'all_clusters_4rows.pdf')

# Filter the data for the specific sample
adata_sample = adata[adata.obs['sample'] == 's2r2_HV184']

# Extract unique clusters in the 'Lvl4' column matching the specified categories
unique_clusters = adata_sample.obs.loc[
    adata_sample.obs['Lvl4'].isin([
        'Treg', 'Th_proximity_to_B', 'Th', 'T.IL7Rhi', 'T.IE', 
         'NK', 'Tc',  'T_proximity_to_Fib','T_proximity_to_BV'
    ]), 
    'Lvl4'
].unique()

# Print the unique clusters
print(unique_clusters)



# Reorder clusters (if a custom order is provided, replace `sorted(unique_clusters)`)
ordered_clusters = sorted(unique_clusters)

# Define the number of rows and columns
num_rows = 4
num_cols = int(np.ceil(len(ordered_clusters) / num_rows))  # Calculate columns based on clusters and rows

# Create a PdfPages object to save the plots
with PdfPages(pdf_filename) as pdf:
    # Create a figure for the sample
    fig, axes = plt.subplots(num_rows, num_cols, figsize=(18, 18))
    fig.patch.set_facecolor('white')

    # Flatten the axes array for easier indexing
    axes = axes.flatten()

    # Get the coordinates for the sample
    x_coords = adata_sample.obs['x_centroid']
    y_coords = adata_sample.obs['y_centroid']
    
    # Apply rotation
    angle = np.deg2rad(rotation_angle)
    new_x_coords = x_coords * np.cos(angle) - y_coords * np.sin(angle)
    new_y_coords = x_coords * np.sin(angle) + y_coords * np.cos(angle)

    # Determine aspect ratio
    x_range = new_x_coords.max() - new_x_coords.min()
    y_range = new_y_coords.max() - new_y_coords.min()
    aspect_ratio = x_range / y_range

       # Loop over each unique cluster in the ordered list
    for idx, cluster in enumerate(ordered_clusters):
        ax = axes[idx]

        # Set white background for the subplot
        ax.set_facecolor('white')

        # Remove the outline
        for spine in ax.spines.values():
            spine.set_visible(False)

        # Scatter plot for the grey dots (all other clusters)
        ax.scatter(
            x=new_x_coords[adata_sample.obs['Lvl4'] != cluster],
            y=new_y_coords[adata_sample.obs['Lvl4'] != cluster],
            c='#C0C0C0', 
            s=3  # Adjust dot size
        )

        # Scatter plot for the red dots (the current cluster)
        ax.scatter(
            x=new_x_coords[adata_sample.obs['Lvl4'] == cluster],
            y=new_y_coords[adata_sample.obs['Lvl4'] == cluster],
            c='red', 
            s=9  # Adjust dot size
        )

        # Set aspect ratio for each subplot
        ax.set_aspect(aspect_ratio)

        # Add the cluster name below the plot
        ax.text(
            0.5, 0.02, f'{cluster}', 
            horizontalalignment='center', 
            verticalalignment='center', 
            transform=ax.transAxes, 
            color='black', fontsize=20, weight='bold'
        )

        # Remove grids
        ax.grid(False)

        # Remove ticks and their labels
        ax.set_xticks([])
        ax.set_yticks([])

    # Turn off empty subplots if there are any
    for ax in axes[len(ordered_clusters):]:
        ax.set_visible(False)

    # Define the directory and file name for the TIFF file
    tiff_filename = os.path.join(save_directory, f'all_clusters_4rows.tiff')

    # Adjust the spacing between subplots
    plt.subplots_adjust(
        left=0.05,    # Space from left edge
        right=0.95,   # Space from right edge
        top=0.95,     # Space from top edge
        bottom=0.05,  # Space from bottom edge
        wspace=0.1,   # Width space between columns
        hspace=0.05    # Height space between rows
    )

    # Add a title to the overall figure
    plt.suptitle(f'All Clusters in s2r2_HV184', color='white', fontsize=20, weight='bold', y=1.02)

    # Save the current figure as a TIFF file
    #fig.savefig(tiff_filename, dpi=300, format='tiff')

    plt.show()
    plt.close(fig)

# %%
import scanpy as sc

# Step 1: Ensure all observation names are unique
adata.obs_names_make_unique()

# Step 2: Subset the data to include categories starting with 'T-' or equal to 'B'
adata_subset = adata[(adata.obs['Lvl4'].isin(['B', 'Pl.1', 'Pl.2', 'PB']))].copy()

# Step 3: Log-transform the data if not already done
sc.pp.log1p(adata_subset)

# Step 4: Perform differential expression analysis using the Wilcoxon method
sc.tl.rank_genes_groups(adata_subset, 'Lvl4', method='wilcoxon', use_raw=False)

# Step 5: Extract top marker genes for each cluster
top_genes_per_cluster = {}
for cluster in adata_subset.obs['Lvl4'].cat.categories:
    top_genes_per_cluster[cluster] = adata_subset.uns['rank_genes_groups']['names'][cluster][:20]  # Top 20 genes

# Step 6: Generate dendrogram for cluster ordering
sc.tl.dendrogram(adata_subset, groupby='Lvl4')

# Step 7: Retrieve the cluster order based on the dendrogram
cluster_order = adata_subset.uns['dendrogram_Lvl4']['categories_ordered']

# Step 8: Filter genes based on 20% expression threshold
filtered_genes = set()
for cluster in cluster_order:
    cluster_data = adata_subset[adata_subset.obs['Lvl4'] == cluster]
    # Calculate the fraction of cells expressing each gene in the cluster
    gene_expression_fraction = (cluster_data.X > 0).mean(axis=0).A1  # Sparse matrix to 1D array
    genes_above_threshold = cluster_data.var_names[gene_expression_fraction > 0.2]
    filtered_genes.update(genes_above_threshold)

# Step 9: Ensure unique genes for plotting
unique_genes = set()
genes_for_plot = []

for cluster in cluster_order:
    if cluster in top_genes_per_cluster:
        cluster_genes = top_genes_per_cluster[cluster]
        genes_for_this_cluster = []
        for gene in cluster_genes:
            if len(genes_for_this_cluster) >= 10:
                break
            if gene in filtered_genes and gene not in unique_genes:
                unique_genes.add(gene)
                genes_for_this_cluster.append(gene)
        genes_for_plot.extend(genes_for_this_cluster)

# Step 10: Plot the dotplot with the filtered genes, swapping axes if necessary
sc.pl.dotplot(
    adata_subset,
    var_names=genes_for_plot,
    groupby='Lvl4',
    dendrogram=True,
    use_raw=False,
    cmap="vlag",
    standard_scale='var',
    swap_axes=True
)

# %%
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.backends.backend_pdf import PdfPages
import os


rotation_angle = 30  # Define rotation for this sample

# Specify the directory where you want to save the PDF
save_directory = '/data/vasileiosionat2/Xenium/Figures/lvl4_pdf/'
pdf_filename = os.path.join(save_directory, f'all_clusters_4rows.pdf')

# Filter the data for the specific sample
adata_sample = adata[adata.obs['sample'] == 's2r2_HV184']

# Extract unique clusters in the 'Lvl4' column matching the specified categories
unique_clusters = adata_sample.obs.loc[
    adata_sample.obs['Lvl4'].isin([
        'B', 'Pl.1', 'Pl.2', 'PB'
    ]), 
    'Lvl4'
].unique()

# Print the unique clusters
print(unique_clusters)



# Reorder clusters (if a custom order is provided, replace `sorted(unique_clusters)`)
ordered_clusters = sorted(unique_clusters)

# Define the number of rows and columns
num_rows = 2
num_cols = int(np.ceil(len(ordered_clusters) / num_rows))  # Calculate columns based on clusters and rows

# Create a PdfPages object to save the plots
with PdfPages(pdf_filename) as pdf:
    # Create a figure for the sample
    fig, axes = plt.subplots(num_rows, num_cols, figsize=(16, 16))
    fig.patch.set_facecolor('white')

    # Flatten the axes array for easier indexing
    axes = axes.flatten()

    # Get the coordinates for the sample
    x_coords = adata_sample.obs['x_centroid']
    y_coords = adata_sample.obs['y_centroid']
    
    # Apply rotation
    angle = np.deg2rad(rotation_angle)
    new_x_coords = x_coords * np.cos(angle) - y_coords * np.sin(angle)
    new_y_coords = x_coords * np.sin(angle) + y_coords * np.cos(angle)

    # Determine aspect ratio
    x_range = new_x_coords.max() - new_x_coords.min()
    y_range = new_y_coords.max() - new_y_coords.min()
    aspect_ratio = x_range / y_range

       # Loop over each unique cluster in the ordered list
    for idx, cluster in enumerate(ordered_clusters):
        ax = axes[idx]

        # Set white background for the subplot
        ax.set_facecolor('white')

        # Remove the outline
        for spine in ax.spines.values():
            spine.set_visible(False)

        # Scatter plot for the grey dots (all other clusters)
        ax.scatter(
            x=new_x_coords[adata_sample.obs['Lvl4'] != cluster],
            y=new_y_coords[adata_sample.obs['Lvl4'] != cluster],
            c='#C0C0C0', 
            s=3  # Adjust dot size
        )

        # Scatter plot for the red dots (the current cluster)
        ax.scatter(
            x=new_x_coords[adata_sample.obs['Lvl4'] == cluster],
            y=new_y_coords[adata_sample.obs['Lvl4'] == cluster],
            c='red', 
            s=9  # Adjust dot size
        )

        # Set aspect ratio for each subplot
        ax.set_aspect(aspect_ratio)

        # Add the cluster name below the plot
        ax.text(
            0.5, 0.02, f'{cluster}', 
            horizontalalignment='center', 
            verticalalignment='center', 
            transform=ax.transAxes, 
            color='black', fontsize=20, weight='bold'
        )

        # Remove grids
        ax.grid(False)

        # Remove ticks and their labels
        ax.set_xticks([])
        ax.set_yticks([])

    # Turn off empty subplots if there are any
    for ax in axes[len(ordered_clusters):]:
        ax.set_visible(False)

    # Define the directory and file name for the TIFF file
    tiff_filename = os.path.join(save_directory, f'all_clusters_4rows.tiff')

    # Adjust the spacing between subplots
    plt.subplots_adjust(
        left=0.05,    # Space from left edge
        right=0.95,   # Space from right edge
        top=0.95,     # Space from top edge
        bottom=0.05,  # Space from bottom edge
        wspace=0.1,   # Width space between columns
        hspace=0.05    # Height space between rows
    )

    # Add a title to the overall figure
    plt.suptitle(f'All Clusters in s2r2_HV184', color='white', fontsize=20, weight='bold', y=1.02)

    # Save the current figure as a TIFF file
    #fig.savefig(tiff_filename, dpi=300, format='tiff')

    plt.show()
    plt.close(fig)

# %%
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.backends.backend_pdf import PdfPages
import os


rotation_angle = 30  # Define rotation for this sample

# Specify the directory where you want to save the PDF
save_directory = '/data/vasileiosionat2/Xenium/Figures/lvl4_pdf/'
pdf_filename = os.path.join(save_directory, f'all_clusters_4rows.pdf')

# Filter the data for the specific sample
adata_sample = adata[adata.obs['sample'] == 's2r1_HV207']

# Extract unique clusters in the 'Lvl4' column matching the specified categories
unique_clusters = adata_sample.obs.loc[
    adata_sample.obs['Lvl4'].isin([
        'B', 'Pl.1', 'Pl.2', 'PB'
    ]), 
    'Lvl4'
].unique()

# Print the unique clusters
print(unique_clusters)



# Reorder clusters (if a custom order is provided, replace `sorted(unique_clusters)`)
ordered_clusters = sorted(unique_clusters)

# Define the number of rows and columns
num_rows = 2
num_cols = int(np.ceil(len(ordered_clusters) / num_rows))  # Calculate columns based on clusters and rows

# Create a PdfPages object to save the plots
with PdfPages(pdf_filename) as pdf:
    # Create a figure for the sample
    fig, axes = plt.subplots(num_rows, num_cols, figsize=(16, 16))
    fig.patch.set_facecolor('white')

    # Flatten the axes array for easier indexing
    axes = axes.flatten()

    # Get the coordinates for the sample
    x_coords = adata_sample.obs['x_centroid']
    y_coords = adata_sample.obs['y_centroid']
    
    # Apply rotation
    angle = np.deg2rad(rotation_angle)
    new_x_coords = x_coords * np.cos(angle) - y_coords * np.sin(angle)
    new_y_coords = x_coords * np.sin(angle) + y_coords * np.cos(angle)

    # Determine aspect ratio
    x_range = new_x_coords.max() - new_x_coords.min()
    y_range = new_y_coords.max() - new_y_coords.min()
    aspect_ratio = x_range / y_range

       # Loop over each unique cluster in the ordered list
    for idx, cluster in enumerate(ordered_clusters):
        ax = axes[idx]

        # Set white background for the subplot
        ax.set_facecolor('white')

        # Remove the outline
        for spine in ax.spines.values():
            spine.set_visible(False)

        # Scatter plot for the grey dots (all other clusters)
        ax.scatter(
            x=new_x_coords[adata_sample.obs['Lvl4'] != cluster],
            y=new_y_coords[adata_sample.obs['Lvl4'] != cluster],
            c='#C0C0C0', 
            s=3  # Adjust dot size
        )

        # Scatter plot for the red dots (the current cluster)
        ax.scatter(
            x=new_x_coords[adata_sample.obs['Lvl4'] == cluster],
            y=new_y_coords[adata_sample.obs['Lvl4'] == cluster],
            c='red', 
            s=9  # Adjust dot size
        )

        # Set aspect ratio for each subplot
        ax.set_aspect(aspect_ratio)

        # Add the cluster name below the plot
        ax.text(
            0.5, 0.02, f'{cluster}', 
            horizontalalignment='center', 
            verticalalignment='center', 
            transform=ax.transAxes, 
            color='black', fontsize=20, weight='bold'
        )

        # Remove grids
        ax.grid(False)

        # Remove ticks and their labels
        ax.set_xticks([])
        ax.set_yticks([])

    # Turn off empty subplots if there are any
    for ax in axes[len(ordered_clusters):]:
        ax.set_visible(False)

    # Define the directory and file name for the TIFF file
    tiff_filename = os.path.join(save_directory, f'all_clusters_4rows.tiff')

    # Adjust the spacing between subplots
    plt.subplots_adjust(
        left=0.05,    # Space from left edge
        right=0.95,   # Space from right edge
        top=0.95,     # Space from top edge
        bottom=0.05,  # Space from bottom edge
        wspace=0.1,   # Width space between columns
        hspace=0.05    # Height space between rows
    )

    # Add a title to the overall figure
    plt.suptitle(f'All Clusters in s2r2_HV184', color='white', fontsize=20, weight='bold', y=1.02)

    # Save the current figure as a TIFF file
    #fig.savefig(tiff_filename, dpi=300, format='tiff')

    plt.show()
    plt.close(fig)

# %%
import scanpy as sc

# Step 1: Ensure all observation names are unique
adata.obs_names_make_unique()

# Step 2: Subset the data to include categories starting with 'T-' or equal to 'B'
adata_subset = adata[(adata.obs['Lvl4'].isin(['Mac', 'Mono', 'cDC1', 'cDC2', 'Mast', 
         'Lang', 'mregDC', 'pDC']))].copy()

# Step 3: Log-transform the data if not already done
sc.pp.log1p(adata_subset)

# Step 4: Perform differential expression analysis using the Wilcoxon method
sc.tl.rank_genes_groups(adata_subset, 'Lvl4', method='wilcoxon', use_raw=False)

# Step 5: Extract top marker genes for each cluster
top_genes_per_cluster = {}
for cluster in adata_subset.obs['Lvl4'].cat.categories:
    top_genes_per_cluster[cluster] = adata_subset.uns['rank_genes_groups']['names'][cluster][:20]  # Top 20 genes

# Step 6: Generate dendrogram for cluster ordering
sc.tl.dendrogram(adata_subset, groupby='Lvl4')

# Step 7: Retrieve the cluster order based on the dendrogram
cluster_order = adata_subset.uns['dendrogram_Lvl4']['categories_ordered']

# Step 8: Filter genes based on 20% expression threshold
filtered_genes = set()
for cluster in cluster_order:
    cluster_data = adata_subset[adata_subset.obs['Lvl4'] == cluster]
    # Calculate the fraction of cells expressing each gene in the cluster
    gene_expression_fraction = (cluster_data.X > 0).mean(axis=0).A1  # Sparse matrix to 1D array
    genes_above_threshold = cluster_data.var_names[gene_expression_fraction > 0.2]
    filtered_genes.update(genes_above_threshold)

# Step 9: Ensure unique genes for plotting
unique_genes = set()
genes_for_plot = []

for cluster in cluster_order:
    if cluster in top_genes_per_cluster:
        cluster_genes = top_genes_per_cluster[cluster]
        genes_for_this_cluster = []
        for gene in cluster_genes:
            if len(genes_for_this_cluster) >= 5:
                break
            if gene in filtered_genes and gene not in unique_genes:
                unique_genes.add(gene)
                genes_for_this_cluster.append(gene)
        genes_for_plot.extend(genes_for_this_cluster)

# Step 10: Plot the dotplot with the filtered genes, swapping axes if necessary
sc.pl.dotplot(
    adata_subset,
    var_names=genes_for_plot,
    groupby='Lvl4',
    dendrogram=True,
    use_raw=False,
    cmap="vlag",
    standard_scale='var',
    swap_axes=True
)

# %%
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.backends.backend_pdf import PdfPages
import os


rotation_angle = 30  # Define rotation for this sample

# Specify the directory where you want to save the PDF
save_directory = '/data/vasileiosionat2/Xenium/Figures/lvl4_pdf/'
pdf_filename = os.path.join(save_directory, f'all_clusters_4rows.pdf')

# Filter the data for the specific sample
adata_sample = adata[adata.obs['sample'] == 's2r2_HV184']

# Extract unique clusters in the 'Lvl4' column matching the specified categories
unique_clusters = adata_sample.obs.loc[
    adata_sample.obs['Lvl4'].isin([
'Mac', 'Mono', 'cDC1', 'cDC2', 'Mast', 
         'Lang', 'mregDC', 'pDC'
    ]), 
    'Lvl4'
].unique()

# Print the unique clusters
print(unique_clusters)



# Reorder clusters (if a custom order is provided, replace `sorted(unique_clusters)`)
ordered_clusters = sorted(unique_clusters)

# Define the number of rows and columns
num_rows = 3
num_cols = int(np.ceil(len(ordered_clusters) / num_rows))  # Calculate columns based on clusters and rows

# Create a PdfPages object to save the plots
with PdfPages(pdf_filename) as pdf:
    # Create a figure for the sample
    fig, axes = plt.subplots(num_rows, num_cols, figsize=(16, 16))
    fig.patch.set_facecolor('white')

    # Flatten the axes array for easier indexing
    axes = axes.flatten()

    # Get the coordinates for the sample
    x_coords = adata_sample.obs['x_centroid']
    y_coords = adata_sample.obs['y_centroid']
    
    # Apply rotation
    angle = np.deg2rad(rotation_angle)
    new_x_coords = x_coords * np.cos(angle) - y_coords * np.sin(angle)
    new_y_coords = x_coords * np.sin(angle) + y_coords * np.cos(angle)

    # Determine aspect ratio
    x_range = new_x_coords.max() - new_x_coords.min()
    y_range = new_y_coords.max() - new_y_coords.min()
    aspect_ratio = x_range / y_range

       # Loop over each unique cluster in the ordered list
    for idx, cluster in enumerate(ordered_clusters):
        ax = axes[idx]

        # Set white background for the subplot
        ax.set_facecolor('white')

        # Remove the outline
        for spine in ax.spines.values():
            spine.set_visible(False)

        # Scatter plot for the grey dots (all other clusters)
        ax.scatter(
            x=new_x_coords[adata_sample.obs['Lvl4'] != cluster],
            y=new_y_coords[adata_sample.obs['Lvl4'] != cluster],
            c='#C0C0C0', 
            s=3  # Adjust dot size
        )

        # Scatter plot for the red dots (the current cluster)
        ax.scatter(
            x=new_x_coords[adata_sample.obs['Lvl4'] == cluster],
            y=new_y_coords[adata_sample.obs['Lvl4'] == cluster],
            c='red', 
            s=9  # Adjust dot size
        )

        # Set aspect ratio for each subplot
        ax.set_aspect(aspect_ratio)

        # Add the cluster name below the plot
        ax.text(
            0.5, 0.02, f'{cluster}', 
            horizontalalignment='center', 
            verticalalignment='center', 
            transform=ax.transAxes, 
            color='black', fontsize=20, weight='bold'
        )

        # Remove grids
        ax.grid(False)

        # Remove ticks and their labels
        ax.set_xticks([])
        ax.set_yticks([])

    # Turn off empty subplots if there are any
    for ax in axes[len(ordered_clusters):]:
        ax.set_visible(False)

    # Define the directory and file name for the TIFF file
    tiff_filename = os.path.join(save_directory, f'all_clusters_4rows.tiff')

    # Adjust the spacing between subplots
    plt.subplots_adjust(
        left=0.05,    # Space from left edge
        right=0.95,   # Space from right edge
        top=0.95,     # Space from top edge
        bottom=0.05,  # Space from bottom edge
        wspace=0.1,   # Width space between columns
        hspace=0.05    # Height space between rows
    )

    # Add a title to the overall figure
    plt.suptitle(f'All Clusters in s2r2_HV184', color='white', fontsize=20, weight='bold', y=1.02)

    # Save the current figure as a TIFF file
    #fig.savefig(tiff_filename, dpi=300, format='tiff')

    plt.show()
    plt.close(fig)

# %%
import scanpy as sc

# Step 1: Ensure all observation names are unique
adata.obs_names_make_unique()

# Step 2: Subset the data to include categories starting with 'T-' or equal to 'B'
adata_subset = adata[(adata.obs['Lvl3'].isin(['Crev', 'Keratin', 'Prol', 'Spinous', 'Basal', 
         'Mel']))].copy()

# Step 3: Log-transform the data if not already done
sc.pp.log1p(adata_subset)

# Step 4: Perform differential expression analysis using the Wilcoxon method
sc.tl.rank_genes_groups(adata_subset, 'Lvl3', method='wilcoxon', use_raw=False)

# Step 5: Extract top marker genes for each cluster
top_genes_per_cluster = {}
for cluster in adata_subset.obs['Lvl3'].cat.categories:
    top_genes_per_cluster[cluster] = adata_subset.uns['rank_genes_groups']['names'][cluster][:20]  # Top 20 genes

# Step 6: Generate dendrogram for cluster ordering
sc.tl.dendrogram(adata_subset, groupby='Lvl3')

# Step 7: Retrieve the cluster order based on the dendrogram
cluster_order = adata_subset.uns['dendrogram_Lvl3']['categories_ordered']

# Step 8: Filter genes based on 20% expression threshold
filtered_genes = set()
for cluster in cluster_order:
    cluster_data = adata_subset[adata_subset.obs['Lvl3'] == cluster]
    # Calculate the fraction of cells expressing each gene in the cluster
    gene_expression_fraction = (cluster_data.X > 0).mean(axis=0).A1  # Sparse matrix to 1D array
    genes_above_threshold = cluster_data.var_names[gene_expression_fraction > 0.2]
    filtered_genes.update(genes_above_threshold)

# Step 9: Ensure unique genes for plotting
unique_genes = set()
genes_for_plot = []

for cluster in cluster_order:
    if cluster in top_genes_per_cluster:
        cluster_genes = top_genes_per_cluster[cluster]
        genes_for_this_cluster = []
        for gene in cluster_genes:
            if len(genes_for_this_cluster) >= 5:
                break
            if gene in filtered_genes and gene not in unique_genes:
                unique_genes.add(gene)
                genes_for_this_cluster.append(gene)
        genes_for_plot.extend(genes_for_this_cluster)

# Step 10: Plot the dotplot with the filtered genes, swapping axes if necessary
sc.pl.dotplot(
    adata_subset,
    var_names=genes_for_plot,
    groupby='Lvl3',
    dendrogram=True,
    use_raw=False,
    cmap="vlag",
    standard_scale='var',
    swap_axes=True
)

# %%
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.backends.backend_pdf import PdfPages
import os


rotation_angle = 30  # Define rotation for this sample

# Specify the directory where you want to save the PDF
save_directory = '/data/vasileiosionat2/Xenium/Figures/lvl4_pdf/'
pdf_filename = os.path.join(save_directory, f'all_clusters_4rows.pdf')

# Filter the data for the specific sample
adata_sample = adata[adata.obs['sample'] == 's2r2_HV184']

# Extract unique clusters in the 'Lvl4' column matching the specified categories
unique_clusters = adata_sample.obs.loc[
    adata_sample.obs['Lvl3'].isin([
       'Crev', 'Keratin', 'Prol', 'Spinous', 'Basal', 
         'Mel'
    ]), 
    'Lvl3'
].unique()

# Print the unique clusters
print(unique_clusters)



# Reorder clusters (if a custom order is provided, replace `sorted(unique_clusters)`)
ordered_clusters = sorted(unique_clusters)

# Define the number of rows and columns
num_rows = 3
num_cols = int(np.ceil(len(ordered_clusters) / num_rows))  # Calculate columns based on clusters and rows

# Create a PdfPages object to save the plots
with PdfPages(pdf_filename) as pdf:
    # Create a figure for the sample
    fig, axes = plt.subplots(num_rows, num_cols, figsize=(16, 16))
    fig.patch.set_facecolor('white')

    # Flatten the axes array for easier indexing
    axes = axes.flatten()

    # Get the coordinates for the sample
    x_coords = adata_sample.obs['x_centroid']
    y_coords = adata_sample.obs['y_centroid']
    
    # Apply rotation
    angle = np.deg2rad(rotation_angle)
    new_x_coords = x_coords * np.cos(angle) - y_coords * np.sin(angle)
    new_y_coords = x_coords * np.sin(angle) + y_coords * np.cos(angle)

    # Determine aspect ratio
    x_range = new_x_coords.max() - new_x_coords.min()
    y_range = new_y_coords.max() - new_y_coords.min()
    aspect_ratio = x_range / y_range

       # Loop over each unique cluster in the ordered list
    for idx, cluster in enumerate(ordered_clusters):
        ax = axes[idx]

        # Set white background for the subplot
        ax.set_facecolor('white')

        # Remove the outline
        for spine in ax.spines.values():
            spine.set_visible(False)

        # Scatter plot for the grey dots (all other clusters)
        ax.scatter(
            x=new_x_coords[adata_sample.obs['Lvl3'] != cluster],
            y=new_y_coords[adata_sample.obs['Lvl3'] != cluster],
            c='#C0C0C0', 
            s=3  # Adjust dot size
        )

        # Scatter plot for the red dots (the current cluster)
        ax.scatter(
            x=new_x_coords[adata_sample.obs['Lvl3'] == cluster],
            y=new_y_coords[adata_sample.obs['Lvl3'] == cluster],
            c='red', 
            s=9  # Adjust dot size
        )

        # Set aspect ratio for each subplot
        ax.set_aspect(aspect_ratio)

        # Add the cluster name below the plot
        ax.text(
            0.5, 0.02, f'{cluster}', 
            horizontalalignment='center', 
            verticalalignment='center', 
            transform=ax.transAxes, 
            color='black', fontsize=20, weight='bold'
        )

        # Remove grids
        ax.grid(False)

        # Remove ticks and their labels
        ax.set_xticks([])
        ax.set_yticks([])

    # Turn off empty subplots if there are any
    for ax in axes[len(ordered_clusters):]:
        ax.set_visible(False)

    # Define the directory and file name for the TIFF file
    tiff_filename = os.path.join(save_directory, f'all_clusters_4rows.tiff')

    # Adjust the spacing between subplots
    plt.subplots_adjust(
        left=0.05,    # Space from left edge
        right=0.95,   # Space from right edge
        top=0.95,     # Space from top edge
        bottom=0.05,  # Space from bottom edge
        wspace=0.1,   # Width space between columns
        hspace=0.05    # Height space between rows
    )

    # Add a title to the overall figure
    plt.suptitle(f'All Clusters in s2r2_HV184', color='white', fontsize=20, weight='bold', y=1.02)

    # Save the current figure as a TIFF file
    #fig.savefig(tiff_filename, dpi=300, format='tiff')

    plt.show()
    plt.close(fig)

# %%
import scanpy as sc

# Step 1: Ensure all observation names are unique
adata.obs_names_make_unique()

# Step 2: Subset the data to include categories starting with 'T-' or equal to 'B'
adata_subset = adata[(adata.obs['Lvl4'].isin(['Fib.1', 'Fib.2', 'Fib.3', 'Fib.4', 'Fib.5', 
         'MyoF', 'Neur']))].copy()

# Step 3: Log-transform the data if not already done
sc.pp.log1p(adata_subset)

# Step 4: Perform differential expression analysis using the Wilcoxon method
sc.tl.rank_genes_groups(adata_subset, 'Lvl4', method='wilcoxon', use_raw=False)

# Step 5: Extract top marker genes for each cluster
top_genes_per_cluster = {}
for cluster in adata_subset.obs['Lvl4'].cat.categories:
    top_genes_per_cluster[cluster] = adata_subset.uns['rank_genes_groups']['names'][cluster][:20]  # Top 20 genes

# Step 6: Generate dendrogram for cluster ordering
sc.tl.dendrogram(adata_subset, groupby='Lvl4')

# Step 7: Retrieve the cluster order based on the dendrogram
cluster_order = adata_subset.uns['dendrogram_Lvl4']['categories_ordered']

# Step 8: Filter genes based on 20% expression threshold
filtered_genes = set()
for cluster in cluster_order:
    cluster_data = adata_subset[adata_subset.obs['Lvl4'] == cluster]
    # Calculate the fraction of cells expressing each gene in the cluster
    gene_expression_fraction = (cluster_data.X > 0).mean(axis=0).A1  # Sparse matrix to 1D array
    genes_above_threshold = cluster_data.var_names[gene_expression_fraction > 0.2]
    filtered_genes.update(genes_above_threshold)

# Step 9: Ensure unique genes for plotting
unique_genes = set()
genes_for_plot = []

for cluster in cluster_order:
    if cluster in top_genes_per_cluster:
        cluster_genes = top_genes_per_cluster[cluster]
        genes_for_this_cluster = []
        for gene in cluster_genes:
            if len(genes_for_this_cluster) >= 5:
                break
            if gene in filtered_genes and gene not in unique_genes:
                unique_genes.add(gene)
                genes_for_this_cluster.append(gene)
        genes_for_plot.extend(genes_for_this_cluster)

# Step 10: Plot the dotplot with the filtered genes, swapping axes if necessary
sc.pl.dotplot(
    adata_subset,
    var_names=genes_for_plot,
    groupby='Lvl4',
    dendrogram=True,
    use_raw=False,
    cmap="vlag",
    standard_scale='var',
    swap_axes=True
)

# %%
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.backends.backend_pdf import PdfPages
import os


rotation_angle = 30  # Define rotation for this sample

# Specify the directory where you want to save the PDF
save_directory = '/data/vasileiosionat2/Xenium/Figures/lvl4_pdf/'
pdf_filename = os.path.join(save_directory, f'all_clusters_4rows.pdf')

# Filter the data for the specific sample
adata_sample = adata[adata.obs['sample'] == 's2r2_HV184']

# Extract unique clusters in the 'Lvl4' column matching the specified categories
unique_clusters = adata_sample.obs.loc[
    adata_sample.obs['Lvl4'].isin([
        'Fib.1', 'Fib.2', 'Fib.3', 'Fib.4', 'Fib.5', 
         'MyoF', 'Neur'
    ]), 
    'Lvl4'
].unique()

# Print the unique clusters
print(unique_clusters)



# Reorder clusters (if a custom order is provided, replace `sorted(unique_clusters)`)
ordered_clusters = sorted(unique_clusters)

# Define the number of rows and columns
num_rows = 2
num_cols = int(np.ceil(len(ordered_clusters) / num_rows))  # Calculate columns based on clusters and rows

# Create a PdfPages object to save the plots
with PdfPages(pdf_filename) as pdf:
    # Create a figure for the sample
    fig, axes = plt.subplots(num_rows, num_cols, figsize=(20, 15))
    fig.patch.set_facecolor('white')

    # Flatten the axes array for easier indexing
    axes = axes.flatten()

    # Get the coordinates for the sample
    x_coords = adata_sample.obs['x_centroid']
    y_coords = adata_sample.obs['y_centroid']
    
    # Apply rotation
    angle = np.deg2rad(rotation_angle)
    new_x_coords = x_coords * np.cos(angle) - y_coords * np.sin(angle)
    new_y_coords = x_coords * np.sin(angle) + y_coords * np.cos(angle)

    # Determine aspect ratio
    x_range = new_x_coords.max() - new_x_coords.min()
    y_range = new_y_coords.max() - new_y_coords.min()
    aspect_ratio = x_range / y_range

       # Loop over each unique cluster in the ordered list
    for idx, cluster in enumerate(ordered_clusters):
        ax = axes[idx]

        # Set white background for the subplot
        ax.set_facecolor('white')

        # Remove the outline
        for spine in ax.spines.values():
            spine.set_visible(False)

        # Scatter plot for the grey dots (all other clusters)
        ax.scatter(
            x=new_x_coords[adata_sample.obs['Lvl4'] != cluster],
            y=new_y_coords[adata_sample.obs['Lvl4'] != cluster],
            c='#C0C0C0', 
            s=3  # Adjust dot size
        )

        # Scatter plot for the red dots (the current cluster)
        ax.scatter(
            x=new_x_coords[adata_sample.obs['Lvl4'] == cluster],
            y=new_y_coords[adata_sample.obs['Lvl4'] == cluster],
            c='red', 
            s=9  # Adjust dot size
        )

        # Set aspect ratio for each subplot
        ax.set_aspect(aspect_ratio)

        # Add the cluster name below the plot
        ax.text(
            0.5, 0.02, f'{cluster}', 
            horizontalalignment='center', 
            verticalalignment='center', 
            transform=ax.transAxes, 
            color='black', fontsize=20, weight='bold'
        )

        # Remove grids
        ax.grid(False)

        # Remove ticks and their labels
        ax.set_xticks([])
        ax.set_yticks([])

    # Turn off empty subplots if there are any
    for ax in axes[len(ordered_clusters):]:
        ax.set_visible(False)

    # Define the directory and file name for the TIFF file
    tiff_filename = os.path.join(save_directory, f'all_clusters_4rows.tiff')

    # Adjust the spacing between subplots
    plt.subplots_adjust(
        left=0.05,    # Space from left edge
        right=0.95,   # Space from right edge
        top=0.95,     # Space from top edge
        bottom=0.05,  # Space from bottom edge
        wspace=0.1,   # Width space between columns
        hspace=0.05    # Height space between rows
    )

    # Add a title to the overall figure
    plt.suptitle(f'All Clusters in s2r2_HV184', color='white', fontsize=20, weight='bold', y=1.02)

    # Save the current figure as a TIFF file
    #fig.savefig(tiff_filename, dpi=300, format='tiff')

    plt.show()
    plt.close(fig)

# %%
import scanpy as sc

# Step 1: Ensure all observation names are unique
adata.obs_names_make_unique()

# Step 2: Subset the data to include categories starting with 'T-' or equal to 'B'
adata_subset = adata[(adata.obs['Lvl4'].isin(['VEC.1', 'VEC.2', 'VEC.3', 'VEC.4', 'VEC.5', 
         'SMC', 'LEC']))].copy()

# Step 3: Log-transform the data if not already done
sc.pp.log1p(adata_subset)

# Step 4: Perform differential expression analysis using the Wilcoxon method
sc.tl.rank_genes_groups(adata_subset, 'Lvl4', method='wilcoxon', use_raw=False)

# Step 5: Extract top marker genes for each cluster
top_genes_per_cluster = {}
for cluster in adata_subset.obs['Lvl4'].cat.categories:
    top_genes_per_cluster[cluster] = adata_subset.uns['rank_genes_groups']['names'][cluster][:20]  # Top 20 genes

# Step 6: Generate dendrogram for cluster ordering
sc.tl.dendrogram(adata_subset, groupby='Lvl4')

# Step 7: Retrieve the cluster order based on the dendrogram
cluster_order = adata_subset.uns['dendrogram_Lvl4']['categories_ordered']

# Step 8: Filter genes based on 20% expression threshold
filtered_genes = set()
for cluster in cluster_order:
    cluster_data = adata_subset[adata_subset.obs['Lvl4'] == cluster]
    # Calculate the fraction of cells expressing each gene in the cluster
    gene_expression_fraction = (cluster_data.X > 0).mean(axis=0).A1  # Sparse matrix to 1D array
    genes_above_threshold = cluster_data.var_names[gene_expression_fraction > 0.2]
    filtered_genes.update(genes_above_threshold)

# Step 9: Ensure unique genes for plotting
unique_genes = set()
genes_for_plot = []

for cluster in cluster_order:
    if cluster in top_genes_per_cluster:
        cluster_genes = top_genes_per_cluster[cluster]
        genes_for_this_cluster = []
        for gene in cluster_genes:
            if len(genes_for_this_cluster) >= 5:
                break
            if gene in filtered_genes and gene not in unique_genes:
                unique_genes.add(gene)
                genes_for_this_cluster.append(gene)
        genes_for_plot.extend(genes_for_this_cluster)

# Step 10: Plot the dotplot with the filtered genes, swapping axes if necessary
sc.pl.dotplot(
    adata_subset,
    var_names=genes_for_plot,
    groupby='Lvl4',
    dendrogram=True,
    use_raw=False,
    cmap="vlag",
    standard_scale='var',
    swap_axes=True
)

# %%
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.backends.backend_pdf import PdfPages
import os


rotation_angle = 30  # Define rotation for this sample

# Specify the directory where you want to save the PDF
save_directory = '/data/vasileiosionat2/Xenium/Figures/lvl4_pdf/'
pdf_filename = os.path.join(save_directory, f'all_clusters_4rows.pdf')

# Filter the data for the specific sample
adata_sample = adata[adata.obs['sample'] == 's2r2_HV184']

# Extract unique clusters in the 'Lvl4' column matching the specified categories
unique_clusters = adata_sample.obs.loc[
    adata_sample.obs['Lvl4'].isin([
       'VEC.1', 'VEC.2', 'VEC.3', 'VEC.4', 'VEC.5', 
         'SMC', 'LEC'
    ]), 
    'Lvl4'
].unique()

# Print the unique clusters
print(unique_clusters)



# Reorder clusters (if a custom order is provided, replace `sorted(unique_clusters)`)
ordered_clusters = sorted(unique_clusters)

# Define the number of rows and columns
num_rows = 3
num_cols = int(np.ceil(len(ordered_clusters) / num_rows))  # Calculate columns based on clusters and rows

# Create a PdfPages object to save the plots
with PdfPages(pdf_filename) as pdf:
    # Create a figure for the sample
    fig, axes = plt.subplots(num_rows, num_cols, figsize=(16, 16))
    fig.patch.set_facecolor('white')

    # Flatten the axes array for easier indexing
    axes = axes.flatten()

    # Get the coordinates for the sample
    x_coords = adata_sample.obs['x_centroid']
    y_coords = adata_sample.obs['y_centroid']
    
    # Apply rotation
    angle = np.deg2rad(rotation_angle)
    new_x_coords = x_coords * np.cos(angle) - y_coords * np.sin(angle)
    new_y_coords = x_coords * np.sin(angle) + y_coords * np.cos(angle)

    # Determine aspect ratio
    x_range = new_x_coords.max() - new_x_coords.min()
    y_range = new_y_coords.max() - new_y_coords.min()
    aspect_ratio = x_range / y_range

       # Loop over each unique cluster in the ordered list
    for idx, cluster in enumerate(ordered_clusters):
        ax = axes[idx]

        # Set white background for the subplot
        ax.set_facecolor('white')

        # Remove the outline
        for spine in ax.spines.values():
            spine.set_visible(False)

        # Scatter plot for the grey dots (all other clusters)
        ax.scatter(
            x=new_x_coords[adata_sample.obs['Lvl4'] != cluster],
            y=new_y_coords[adata_sample.obs['Lvl4'] != cluster],
            c='#C0C0C0', 
            s=3  # Adjust dot size
        )

        # Scatter plot for the red dots (the current cluster)
        ax.scatter(
            x=new_x_coords[adata_sample.obs['Lvl4'] == cluster],
            y=new_y_coords[adata_sample.obs['Lvl4'] == cluster],
            c='red', 
            s=9  # Adjust dot size
        )

        # Set aspect ratio for each subplot
        ax.set_aspect(aspect_ratio)

        # Add the cluster name below the plot
        ax.text(
            0.5, 0.02, f'{cluster}', 
            horizontalalignment='center', 
            verticalalignment='center', 
            transform=ax.transAxes, 
            color='black', fontsize=20, weight='bold'
        )

        # Remove grids
        ax.grid(False)

        # Remove ticks and their labels
        ax.set_xticks([])
        ax.set_yticks([])

    # Turn off empty subplots if there are any
    for ax in axes[len(ordered_clusters):]:
        ax.set_visible(False)

    # Define the directory and file name for the TIFF file
    tiff_filename = os.path.join(save_directory, f'all_clusters_4rows.tiff')

    # Adjust the spacing between subplots
    plt.subplots_adjust(
        left=0.05,    # Space from left edge
        right=0.95,   # Space from right edge
        top=0.95,     # Space from top edge
        bottom=0.05,  # Space from bottom edge
        wspace=0.1,   # Width space between columns
        hspace=0.05    # Height space between rows
    )

    # Add a title to the overall figure
    plt.suptitle(f'All Clusters in s2r2_HV184', color='white', fontsize=20, weight='bold', y=1.02)

    # Save the current figure as a TIFF file
    #fig.savefig(tiff_filename, dpi=300, format='tiff')

    plt.show()
    plt.close(fig)

# %%
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.backends.backend_pdf import PdfPages
import os

# Define rotation angle
rotation_angle = 30

# Specify the directory for saving plots
save_directory = '/data/vasileiosionat2/Xenium/Figures/lvl4_pdf/'
pdf_filename = os.path.join(save_directory, 'epithelial_lvl1_clusters.pdf')

# Filter data for the first 10 samples
unique_samples = adata.obs['sample'].unique()[:45]  # Get the first 10 unique samples

# Create a PdfPages object to save all plots in a single PDF
with PdfPages(pdf_filename) as pdf:
    for sample in unique_samples:
        # Filter the data for the current sample
        adata_sample = adata[adata.obs['sample'] == sample]
        
        # Extract unique clusters in the 'Lvl1' column matching "Epithelial"
        unique_clusters = adata_sample.obs.loc[
            adata_sample.obs['Lvl2'] == 'Oral Epi', 'Lvl2'
        ].unique()

        if len(unique_clusters) == 0:
            print(f"No 'Epithelial' clusters found in sample: {sample}")
            continue

        # Prepare coordinates and apply rotation
        x_coords = adata_sample.obs['x_centroid']
        y_coords = adata_sample.obs['y_centroid']
        angle = np.deg2rad(rotation_angle)
        new_x_coords = x_coords * np.cos(angle) - y_coords * np.sin(angle)
        new_y_coords = x_coords * np.sin(angle) + y_coords * np.cos(angle)

        # Determine aspect ratio
        x_range = new_x_coords.max() - new_x_coords.min()
        y_range = new_y_coords.max() - new_y_coords.min()
        aspect_ratio = x_range / y_range

        # Create the plot
        fig, ax = plt.subplots(figsize=(8, 8))
        fig.patch.set_facecolor('white')
        ax.set_facecolor('white')

        # Scatter plot for other clusters (grey)
        ax.scatter(
            new_x_coords[adata_sample.obs['Lvl2'] != 'Oral Epi'],
            new_y_coords[adata_sample.obs['Lvl2'] != 'Oral Epi'],
            c='#C0C0C0', s=3, label='Other clusters'
        )

        # Scatter plot for the "Epithelial" cluster (red)
        ax.scatter(
            new_x_coords[adata_sample.obs['Lvl2'] == 'Oral Epi'],
            new_y_coords[adata_sample.obs['Lvl2'] == 'Oral Epi'],
            c='red', s=9, label='Crev'
        )

        # Set aspect ratio and title
        ax.set_aspect(aspect_ratio)
        ax.set_title(f'{sample} - Crevicular', fontsize=20, color='black', weight='bold')

        # Remove axes and grid
        ax.set_xticks([])
        ax.set_yticks([])
        ax.grid(False)

        # Save the current plot to the PDF
        #pdf.savefig(fig)
        plt.show(fig)

print(f"PDF saved to: {pdf_filename}")

# %%
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.backends.backend_pdf import PdfPages
import os

# Define rotation angle
rotation_angle = 30

# Specify the directory for saving plots
save_directory = '/data/vasileiosionat2/Xenium/Figures/lvl4_pdf/'
pdf_filename = os.path.join(save_directory, 'epithelial_lvl1_clusters.pdf')

# Filter data for the first 10 samples
unique_samples = adata.obs['sample'].unique()[:45]  # Get the first 10 unique samples

# Create a PdfPages object to save all plots in a single PDF
with PdfPages(pdf_filename) as pdf:
    for sample in unique_samples:
        # Filter the data for the current sample
        adata_sample = adata[adata.obs['sample'] == sample]
        
        # Extract unique clusters in the 'Lvl1' column matching "Epithelial"
        unique_clusters = adata_sample.obs.loc[
            adata_sample.obs['Lvl2'] == 'Crevicular Epi', 'Lvl2'
        ].unique()

        if len(unique_clusters) == 0:
            print(f"No 'Epithelial' clusters found in sample: {sample}")
            continue

        # Prepare coordinates and apply rotation
        x_coords = adata_sample.obs['x_centroid']
        y_coords = adata_sample.obs['y_centroid']
        angle = np.deg2rad(rotation_angle)
        new_x_coords = x_coords * np.cos(angle) - y_coords * np.sin(angle)
        new_y_coords = x_coords * np.sin(angle) + y_coords * np.cos(angle)

        # Determine aspect ratio
        x_range = new_x_coords.max() - new_x_coords.min()
        y_range = new_y_coords.max() - new_y_coords.min()
        aspect_ratio = x_range / y_range

        # Create the plot
        fig, ax = plt.subplots(figsize=(8, 8))
        fig.patch.set_facecolor('white')
        ax.set_facecolor('white')

        # Scatter plot for other clusters (grey)
        ax.scatter(
            new_x_coords[adata_sample.obs['Lvl2'] != 'Crevicular Epi'],
            new_y_coords[adata_sample.obs['Lvl2'] != 'Crevicular Epi'],
            c='#C0C0C0', s=3, label='Other clusters'
        )

        # Scatter plot for the "Epithelial" cluster (red)
        ax.scatter(
            new_x_coords[adata_sample.obs['Lvl2'] == 'Crevicular Epi'],
            new_y_coords[adata_sample.obs['Lvl2'] == 'Crevicular Epi'],
            c='red', s=9, label='Crev'
        )

        # Set aspect ratio and title
        ax.set_aspect(aspect_ratio)
        ax.set_title(f'{sample} - Crevicular', fontsize=20, color='black', weight='bold')

        # Remove axes and grid
        ax.set_xticks([])
        ax.set_yticks([])
        ax.grid(False)

        # Save the current plot to the PDF
        #pdf.savefig(fig)
        plt.show(fig)

print(f"PDF saved to: {pdf_filename}")

# %%
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.backends.backend_pdf import PdfPages
import os

# Define rotation angle
rotation_angle = 30

# Specify the directory for saving plots
save_directory = '/data/vasileiosionat2/Xenium/Figures/lvl4_pdf/'
pdf_filename = os.path.join(save_directory, 'epithelial_lvl1_clusters.pdf')

# Filter data for the first 10 samples
unique_samples = adata.obs['sample'].unique()[:45]  # Get the first 10 unique samples

# Create a PdfPages object to save all plots in a single PDF
with PdfPages(pdf_filename) as pdf:
    for sample in unique_samples:
        # Filter the data for the current sample
        adata_sample = adata[adata.obs['sample'] == sample]
        
        # Extract unique clusters in the 'Lvl1' column matching "Epithelial"
        unique_clusters = adata_sample.obs.loc[
            adata_sample.obs['niche_cc14'] == 'Lymphoid', 'niche_cc14'
        ].unique()

        if len(unique_clusters) == 0:
            print(f"No 'Epithelial' clusters found in sample: {sample}")
            continue

        # Prepare coordinates and apply rotation
        x_coords = adata_sample.obs['x_centroid']
        y_coords = adata_sample.obs['y_centroid']
        angle = np.deg2rad(rotation_angle)
        new_x_coords = x_coords * np.cos(angle) - y_coords * np.sin(angle)
        new_y_coords = x_coords * np.sin(angle) + y_coords * np.cos(angle)

        # Determine aspect ratio
        x_range = new_x_coords.max() - new_x_coords.min()
        y_range = new_y_coords.max() - new_y_coords.min()
        aspect_ratio = x_range / y_range

        # Create the plot
        fig, ax = plt.subplots(figsize=(8, 8))
        fig.patch.set_facecolor('white')
        ax.set_facecolor('white')

        # Scatter plot for other clusters (grey)
        ax.scatter(
            new_x_coords[adata_sample.obs['niche_cc14'] != 'Lymphoid'],
            new_y_coords[adata_sample.obs['niche_cc14'] != 'Lymphoid'],
            c='#C0C0C0', s=3, label='Other clusters'
        )

        # Scatter plot for the "Epithelial" cluster (red)
        ax.scatter(
            new_x_coords[adata_sample.obs['niche_cc14'] == 'Lymphoid'],
            new_y_coords[adata_sample.obs['niche_cc14'] == 'Lymphoid'],
            c='red', s=9, label='Lymphoid'
        )

        # Set aspect ratio and title
        ax.set_aspect(aspect_ratio)
        ax.set_title(f'{sample} - Lymphoid', fontsize=20, color='black', weight='bold')

        # Remove axes and grid
        ax.set_xticks([])
        ax.set_yticks([])
        ax.grid(False)

        # Save the current plot to the PDF
        #pdf.savefig(fig)
        plt.show(fig)

print(f"PDF saved to: {pdf_filename}")

# %%
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.backends.backend_pdf import PdfPages
import os

# Define rotation angle
rotation_angle = 30

# Specify the directory for saving plots
save_directory = '/data/vasileiosionat2/Xenium/Figures/lvl4_pdf/'
pdf_filename = os.path.join(save_directory, 'epithelial_lvl1_clusters.pdf')

# Filter data for the first 10 samples
unique_samples = adata.obs['sample'].unique()[:45]  # Get the first 10 unique samples

# Create a PdfPages object to save all plots in a single PDF
with PdfPages(pdf_filename) as pdf:
    for sample in unique_samples:
        # Filter the data for the current sample
        adata_sample = adata[adata.obs['sample'] == sample]
        
        # Extract unique clusters in the 'Lvl1' column matching "Epithelial"
        unique_clusters = adata_sample.obs.loc[
            adata_sample.obs['niche_cc14'] == 'Plasma', 'niche_cc14'
        ].unique()

        if len(unique_clusters) == 0:
            print(f"No 'Epithelial' clusters found in sample: {sample}")
            continue

        # Prepare coordinates and apply rotation
        x_coords = adata_sample.obs['x_centroid']
        y_coords = adata_sample.obs['y_centroid']
        angle = np.deg2rad(rotation_angle)
        new_x_coords = x_coords * np.cos(angle) - y_coords * np.sin(angle)
        new_y_coords = x_coords * np.sin(angle) + y_coords * np.cos(angle)

        # Determine aspect ratio
        x_range = new_x_coords.max() - new_x_coords.min()
        y_range = new_y_coords.max() - new_y_coords.min()
        aspect_ratio = x_range / y_range

        # Create the plot
        fig, ax = plt.subplots(figsize=(8, 8))
        fig.patch.set_facecolor('white')
        ax.set_facecolor('white')

        # Scatter plot for other clusters (grey)
        ax.scatter(
            new_x_coords[adata_sample.obs['niche_cc14'] != 'Plasma'],
            new_y_coords[adata_sample.obs['niche_cc14'] != 'Plasma'],
            c='#C0C0C0', s=3, label='Other clusters'
        )

        # Scatter plot for the "Epithelial" cluster (red)
        ax.scatter(
            new_x_coords[adata_sample.obs['niche_cc14'] == 'Plasma'],
            new_y_coords[adata_sample.obs['niche_cc14'] == 'Plasma'],
            c='red', s=9, label='Plasma'
        )

        # Set aspect ratio and title
        ax.set_aspect(aspect_ratio)
        ax.set_title(f'{sample} - Plasma', fontsize=20, color='black', weight='bold')

        # Remove axes and grid
        ax.set_xticks([])
        ax.set_yticks([])
        ax.grid(False)

        # Save the current plot to the PDF
        #pdf.savefig(fig)
        plt.show(fig)

print(f"PDF saved to: {pdf_filename}")

# %%
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.backends.backend_pdf import PdfPages
import os

# Define rotation angle
rotation_angle = 30

# Specify the directory for saving plots
save_directory = '/data/vasileiosionat2/Xenium/Figures/lvl4_pdf/'
pdf_filename = os.path.join(save_directory, 'epithelial_lvl1_clusters.pdf')

# Filter data for the first 10 samples
unique_samples = adata.obs['sample'].unique()[:45]  # Get the first 10 unique samples

# Create a PdfPages object to save all plots in a single PDF
with PdfPages(pdf_filename) as pdf:
    for sample in unique_samples:
        # Filter the data for the current sample
        adata_sample = adata[adata.obs['sample'] == sample]
        
        # Extract unique clusters in the 'Lvl1' column matching "Epithelial"
        unique_clusters = adata_sample.obs.loc[
            adata_sample.obs['Lvl2'] == 'B/Plasma', 'Lvl2'
        ].unique()

        if len(unique_clusters) == 0:
            print(f"No 'Epithelial' clusters found in sample: {sample}")
            continue

        # Prepare coordinates and apply rotation
        x_coords = adata_sample.obs['x_centroid']
        y_coords = adata_sample.obs['y_centroid']
        angle = np.deg2rad(rotation_angle)
        new_x_coords = x_coords * np.cos(angle) - y_coords * np.sin(angle)
        new_y_coords = x_coords * np.sin(angle) + y_coords * np.cos(angle)

        # Determine aspect ratio
        x_range = new_x_coords.max() - new_x_coords.min()
        y_range = new_y_coords.max() - new_y_coords.min()
        aspect_ratio = x_range / y_range

        # Create the plot
        fig, ax = plt.subplots(figsize=(8, 8))
        fig.patch.set_facecolor('white')
        ax.set_facecolor('white')

        # Scatter plot for other clusters (grey)
        ax.scatter(
            new_x_coords[adata_sample.obs['Lvl2'] != 'B/Plasma'],
            new_y_coords[adata_sample.obs['Lvl2'] != 'B/Plasma'],
            c='#C0C0C0', s=3, label='Other clusters'
        )

        # Scatter plot for the "Epithelial" cluster (red)
        ax.scatter(
            new_x_coords[adata_sample.obs['Lvl2'] == 'B/Plasma'],
            new_y_coords[adata_sample.obs['Lvl2'] == 'B/Plasma'],
            c='red', s=9, label='Lymphoid'
        )

        # Set aspect ratio and title
        ax.set_aspect(aspect_ratio)
        ax.set_title(f'{sample} - B/Plasma', fontsize=20, color='black', weight='bold')

        # Remove axes and grid
        ax.set_xticks([])
        ax.set_yticks([])
        ax.grid(False)

        # Save the current plot to the PDF
        #pdf.savefig(fig)
        plt.show(fig)

print(f"PDF saved to: {pdf_filename}")

# %%
adata.obs['Lvl2.5'].unique().tolist()

# %%
adata.obs['Lvl2.5'] = adata.obs['Lvl2.5'].astype(str)
# Convert the 'niche_cc14' column to categorical
adata.obs['Lvl2.5'] = pd.Categorical(adata.obs['Lvl2.5'])

# Define the replacement dictionary
replacement_dict = {
    'Mono' : 'mAPC',
    'Mac' : 'mAPC',
    'DC': 'mAPC',
    'Prol' : 'Basal',
    'Lang' : 'mAPC',
    'MyoF' : 'Fib',
    'LEC' : 'VEC'
   }


# Replace values in the 'niche_cc14' column
adata.obs['Lvl2.5'] = adata.obs['Lvl2.5'].replace(replacement_dict)
print(adata.obs['Lvl2.5'].unique().tolist())

# %%
import pandas as pd

# Assuming `adata.obs` is your DataFrame
adata.obs['Lvl2.5'] = adata.obs.apply(
    lambda row: 'Other' if row['Lvl4'] == 'pDC' else row['Lvl2.5'],
    axis=1
)

# %%
import pandas as pd

# Assuming adata.obs contains 'Lvl4' and 'Lvl5'
cluster_counts = (
    adata.obs.groupby(['Lvl2.5', 'Lvl3']).size().unstack(fill_value=0)
)

# Adjust Pandas display settings to show all rows and all columns
pd.set_option('display.max_columns', None)  # Show all columns
pd.set_option('display.max_rows', None)     # Show all rows
pd.set_option('display.width', None)       # Avoid line breaks for wide DataFrames

# Display the full result
print(cluster_counts)

# Reset the options if needed (optional)
pd.reset_option('display.max_columns')
pd.reset_option('display.max_rows')
pd.reset_option('display.width')

# %%
#After T cell clustering save
adata.write_h5ad("/data/vasileiosionat2/Xenium/Drake_outputs/ccProcessed.h5ad")

# %%
adata.obs.loc[adata.obs['Lvl4'].isin(['T.B.Mix', 'Mac.Neut.Mix']), 'Lvl1'] = 'Immune'

# %%
adata.obs.loc[adata.obs['Lvl4'].isin(['Mac.Neut.Mix']), 'Lvl2'] = 'Myeloid'

# %%
import pandas as pd

# Assuming adata.obs contains 'Lvl4' and 'Lvl5'
cluster_counts = (
    adata.obs.groupby(['Lvl1', 'Lvl4']).size().unstack(fill_value=0)
)

# Adjust Pandas display settings to show all rows and all columns
pd.set_option('display.max_columns', None)  # Show all columns
pd.set_option('display.max_rows', None)     # Show all rows
pd.set_option('display.width', None)       # Avoid line breaks for wide DataFrames

# Display the full result
print(cluster_counts)

# Reset the options if needed (optional)
pd.reset_option('display.max_columns')
pd.reset_option('display.max_rows')
pd.reset_option('display.width')

# %%
import pandas as pd

# Assuming adata.obs contains 'Lvl4' and 'Lvl5'
cluster_counts = (
    adata.obs.groupby(['Lvl2', 'Lvl4']).size().unstack(fill_value=0)
)

# Adjust Pandas display settings to show all rows and all columns
pd.set_option('display.max_columns', None)  # Show all columns
pd.set_option('display.max_rows', None)     # Show all rows
pd.set_option('display.width', None)       # Avoid line breaks for wide DataFrames

# Display the full result
print(cluster_counts)

# Reset the options if needed (optional)
pd.reset_option('display.max_columns')
pd.reset_option('display.max_rows')
pd.reset_option('display.width')
